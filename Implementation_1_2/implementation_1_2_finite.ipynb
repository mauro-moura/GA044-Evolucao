# %%
import sys

ROOT_DIR = '..'
sys.path.append(ROOT_DIR)

# %%
import numpy as np

# %%
from utils.mutation_experiments import run_experiment_with_population

# %% [markdown]
# # Mutação Unidimensional

# %%
u_list = [1e-6]
v_list = [0]
p0_list = [0.7]
q0_list = [1 - p0 for p0 in p0_list]
pop_list = [5, 10, 100, 1000]

t = np.arange(1e5).astype(int)
n = 1

for pop_size in pop_list:
    print(f"Running experiment with population size {pop_size}")
    run_experiment_with_population(u_list, v_list, p0_list, q0_list, pop_size, t, n)
# Out:
# Running experiment with population size 5
#  p inicial, 0.7, q inicial, 0.30000000000000004
# Estagnation in Gen 1
#  p: 0.6999993 q: 0.30000070000000006
# Final p: 0.633386794340814, Final q: 0.3666132056572665
# Estag Gen u=1e-06, v=0, Pop=0.7000x0.3000: 1
# Running experiment with population size 10
#  p inicial, 0.7, q inicial, 0.30000000000000004
# Estagnation in Gen 2
#  p: 0.6999986000007 q: 0.3000013999993001
# Final p: 0.633386794340814, Final q: 0.3666132056572665
# Estag Gen u=1e-06, v=0, Pop=0.7000x0.3000: 2
# Running experiment with population size 100
#  p inicial, 0.7, q inicial, 0.30000000000000004
# Estagnation in Gen 2
#  p: 0.6999986000007 q: 0.3000013999993001
# Not in EHW in gen 94641
# Final p: 0.633386794340814, Final q: 0.3666132056572665
# Estag Gen u=1e-06, v=0, Pop=0.7000x0.3000: 2
# End of EHW (u=1e-06, v=0, Pop=0.7000x0.3000) Gen = 94641
# Running experiment with population size 1000
#  p inicial, 0.7, q inicial, 0.30000000000000004
# Estagnation in Gen 2
#  p: 0.6999986000007 q: 0.3000013999993001
# Not in EHW in gen 29097
# Final p: 0.633386794340814, Final q: 0.3666132056572665
# Estag Gen u=1e-06, v=0, Pop=0.7000x0.3000: 2
# End of EHW (u=1e-06, v=0, Pop=0.7000x0.3000) Gen = 29097

# %% [markdown]
# # Mutação Bidirecional

# %%
u_list = [1e-6]
v_list = [1e-7]
p0_list = [0.7]
q0_list = [1 - p0 for p0 in p0_list]
pop_list = [5, 10, 100, 1000]

t = np.arange(1e5).astype(int)
n = 1

for pop_size in pop_list:
    print(f"Running experiment with population size {pop_size}")
    run_experiment_with_population(u_list, v_list, p0_list, q0_list, pop_size, t, n)
# Out:
# Running experiment with population size 5
#  p inicial, 0.7, q inicial, 0.30000000000000004
# Estagnation in Gen 1
#  p: 0.69999933 q: 0.3000006700000001
# Final p: 0.6365540859677055, Final q: 0.36344591403214616
# Estag Gen u=1e-06, v=1e-07, Pop=0.7000x0.3000: 1
# Running experiment with population size 10
#  p inicial, 0.7, q inicial, 0.30000000000000004
# Estagnation in Gen 2
#  p: 0.699998660000737 q: 0.3000013399992631
# Final p: 0.6365540859677055, Final q: 0.36344591403214616
# Estag Gen u=1e-06, v=1e-07, Pop=0.7000x0.3000: 2
# Running experiment with population size 100
#  p inicial, 0.7, q inicial, 0.30000000000000004
# Estagnation in Gen 2
#  p: 0.699998660000737 q: 0.3000013399992631
# Not in EHW in gen 99607
# Final p: 0.6365540859677055, Final q: 0.36344591403214616
# Estag Gen u=1e-06, v=1e-07, Pop=0.7000x0.3000: 2
# End of EHW (u=1e-06, v=1e-07, Pop=0.7000x0.3000) Gen = 99607
# Running experiment with population size 1000
#  p inicial, 0.7, q inicial, 0.30000000000000004
# Estagnation in Gen 2
#  p: 0.699998660000737 q: 0.3000013399992631
# Not in EHW in gen 30467
# Final p: 0.6365540859677055, Final q: 0.36344591403214616
# Estag Gen u=1e-06, v=1e-07, Pop=0.7000x0.3000: 2
# End of EHW (u=1e-06, v=1e-07, Pop=0.7000x0.3000) Gen = 30467
