# %%
import sys

ROOT_DIR = '..'
sys.path.append(ROOT_DIR)

# %%
import numpy as np

# %%
from utils.mutation_experiments import run_experiment_with_population

# %% [markdown]
# # Mutação Unidimensional

# %%
u_list = [1e-6]
v_list = [0]
p0_list = [0.7]
q0_list = [1 - p0 for p0 in p0_list]
pop_list = [5, 10, 100, 1000]

t = np.arange(1e5).astype(int)
n = 1

for pop_size in pop_list:
    pop_size = pop_size * 2
    print(f"Running experiment with population size {pop_size}")
    run_experiment_with_population(u_list, v_list, p0_list, q0_list, pop_size, t, n)
# Out:
# Running experiment with population size 10
#  p inicial, 0.7, q inicial, 0.30000000000000004
# Estagnation in Gen 1
#  p: 0.7 q: 0.30000000000000004
# Final p: 0.7, Final q: 0.30000000000000004
# Estag Gen u=1e-06, v=0, Pop=0.7000x0.3000: 1
# Running experiment with population size 20
#  p inicial, 0.7, q inicial, 0.30000000000000004
# Estagnation in Gen 1
#  p: 0.7 q: 0.30000000000000004
# Final p: 0.65, Final q: 0.35
# Estag Gen u=1e-06, v=0, Pop=0.7000x0.3000: 1
# Running experiment with population size 200
#  p inicial, 0.7, q inicial, 0.30000000000000004
# Estagnation in Gen 1
#  p: 0.7 q: 0.30000000000000004
# Not in EHW in gen 51380
# Final p: 0.61, Final q: 0.39
# Estag Gen u=1e-06, v=0, Pop=0.7000x0.3000: 1
# End of EHW (u=1e-06, v=0, Pop=0.7000x0.3000) Gen = 51380
# Running experiment with population size 2000
#  p inicial, 0.7, q inicial, 0.30000000000000004
# Estagnation in Gen 1
#  p: 0.7 q: 0.30000000000000004
# Not in EHW in gen 17202
# Final p: 0.638, Final q: 0.362
# ...

# %% [markdown]
# # Mutação Bidirecional

# %%
u_list = [1e-6]
v_list = [1e-7]
p0_list = [0.7]
q0_list = [1 - p0 for p0 in p0_list]
pop_list = [5, 10, 100, 1000]

t = np.arange(1e5).astype(int)
n = 1

for pop_size in pop_list:
    print(f"Running experiment with population size {pop_size}")
    run_experiment_with_population(u_list, v_list, p0_list, q0_list, pop_size, t, n)
# Out:
# Running experiment with population size 5
#  p inicial, 0.7, q inicial, 0.30000000000000004
# Estagnation in Gen 1
#  p: 0.6 q: 0.4
# Final p: 0.6, Final q: 0.4
# Estag Gen u=1e-06, v=1e-07, Pop=0.7000x0.3000: 1
# Running experiment with population size 10
#  p inicial, 0.7, q inicial, 0.30000000000000004
# Estagnation in Gen 1
#  p: 0.7 q: 0.30000000000000004
# Final p: 0.7, Final q: 0.30000000000000004
# Estag Gen u=1e-06, v=1e-07, Pop=0.7000x0.3000: 1
# Running experiment with population size 100
#  p inicial, 0.7, q inicial, 0.30000000000000004
# Estagnation in Gen 1
#  p: 0.7 q: 0.30000000000000004
# Not in EHW in gen 90669
# Final p: 0.62, Final q: 0.38
# Estag Gen u=1e-06, v=1e-07, Pop=0.7000x0.3000: 1
# End of EHW (u=1e-06, v=1e-07, Pop=0.7000x0.3000) Gen = 90669
# Running experiment with population size 1000
#  p inicial, 0.7, q inicial, 0.30000000000000004
# Estagnation in Gen 1
#  p: 0.7 q: 0.30000000000000004
# Not in EHW in gen 20456
# Final p: 0.636, Final q: 0.364
# ...
